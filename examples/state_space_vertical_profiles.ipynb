# %% [markdown]
# # <center>State space vertical profile timeseries for assimilation stages, increments and biases</center>

# %% [raw]
# Example notebook for timeseries of the vertical profiles in state space of different DART assimilation stages, the increments between then and biases from a truth run in the Community Atmosphere Model (CAM) or Community Earth System Model (2) (CESM/CESM2) with CAM.
#
# Forecast, output and standard deviation files are output directly by DART during assimilation experiments. Edits to input.nml may be required to get these files to be output. Other stages in the assimilation can also be output, and may be more appropriate to show depending on your experimental set-up.
#
# Means are not calculated with an area weighting as these were developed for the variable resolution "ARCTIC" grid, which is 1 x ncol making area weighting kinda complicated. The best solution would probably be to regrid onto a lat/lon grid and add some latitude based scaling if an accurate mean is preferred. For data already on a nlatxnlon grid some tweaks to the code would be needed.
#
# N.B. mean absolute error is used for some plots. Root mean square error may be more appropriate.

# %%
from dartplot import state

# %%
state.calculate_vmean_timeseries?
# Out:
# Signature:
# state.calculate_vmean_timeseries(
#     archive,
#     truth,
#     exp,
#     var,
#     value,
#     abs,
#     start_ind=False,
#     end_ind=False,
#     step=False,
# )
# Docstring:
# Wrapper for all the vertical profile calculating functions
#
# e.g. inputs:
# archive =  "/glade/derecho/scratch/chennuo/archive"
# truth = "CESM2_2_BHIST_ne0ARCTICne30x4_g17_derecho_2560pes_spinup_allvars_from_20200701_2mos.004"
# exp = "FHIST_exp.1A_0001"
# var = 'T'
# abs = True if want magnitude, False if want bias - Decides if using absolute error and increment
#
# value_options:
# "forecast_error", "output_error", "increment", "improvement",
# "forecast_sd", "output_sd", "ratio_sd"
# File:      /glade/work/rclancy/ARCTIC_DA/analysis/diag_package/state.py
# Type:      function

# %% [markdown]
# ### Forecast error
# Output error plotted similarly

# %%
# Edit archive and truth to point to your own data before running as this example data may not exist in the future...
# ...and if you're not using the glade filesystem it cetainly won't exist...
archive =  "/glade/derecho/scratch/chennuo/archive"
truth = "CESM2_2_BHIST_ne0ARCTICne30x4_g17_derecho_2560pes_spinup_allvars_from_20200701_2mos.004"
exp = "FHIST_exp.1A_0001"
var = 'T'
value = "forecast_error"

vmeans, levs, times = state.calculate_vmean_timeseries(archive, truth, exp, var, value, abs=True)
fig, ax = state.pcolor_vmean_timeseries(vmeans, times, levs, label=var, title=f"{exp}\n{value}", cmap='magma')

vmeans, levs, times = state.calculate_vmean_timeseries(archive, truth, exp, var, value, abs=False)
fig, ax = state.pcolor_vmean_timeseries(vmeans, times, levs, label=var, title=f"{exp}\n{value}", clim_even=True, cmap='PuOr_r')

# %% [markdown]
# ### Increment

# %%
archive =  "/glade/derecho/scratch/chennuo/archive"
truth = "CESM2_2_BHIST_ne0ARCTICne30x4_g17_derecho_2560pes_spinup_allvars_from_20200701_2mos.004"
exp = "FHIST_exp.1A_0001"
var = 'T'
value = "increment"

vmeans, levs, times = state.calculate_vmean_timeseries(archive, truth, exp, var, value, abs=True)
fig, ax = state.pcolor_vmean_timeseries(vmeans, times, levs, label=var, title=f"{exp}\n{value}", cmap='magma')

vmeans, levs, times = state.calculate_vmean_timeseries(archive, truth, exp, var, value, abs=False)
fig, ax = state.pcolor_vmean_timeseries(vmeans, times, levs, label=var, title=f"{exp}\n{value}", clim_even=True, cmap='PuOr_r')

# %% [markdown]
# ### Improvement

# %%
archive =  "/glade/derecho/scratch/chennuo/archive"
truth = "CESM2_2_BHIST_ne0ARCTICne30x4_g17_derecho_2560pes_spinup_allvars_from_20200701_2mos.004"
exp = "FHIST_exp.1A_0001"
var = 'T'
value = "improvement"

vmeans, levs, times = state.calculate_vmean_timeseries(archive, truth, exp, var, value, abs=True)
fig, ax = state.pcolor_vmean_timeseries(vmeans, times, levs, label=var, title=f"{exp}\n{value}", cmap='magma')

# %% [markdown]
# ### Forecast standard deviation

# %%
archive =  "/glade/derecho/scratch/chennuo/archive"
truth = "CESM2_2_BHIST_ne0ARCTICne30x4_g17_derecho_2560pes_spinup_allvars_from_20200701_2mos.004"
exp = "FHIST_exp.1A_0001"
var = 'T'
value = "forecast_sd"

vmeans, levs, times = state.calculate_vmean_timeseries(archive, truth, exp, var, value, abs=False)
fig, ax = state.pcolor_vmean_timeseries(vmeans, times, levs, label=var, title=f"{exp}\n{value}", cmap='magma')

# %% [markdown]
# ### Output standard deviation

# %%
archive =  "/glade/derecho/scratch/chennuo/archive"
truth = "CESM2_2_BHIST_ne0ARCTICne30x4_g17_derecho_2560pes_spinup_allvars_from_20200701_2mos.004"
exp = "FHIST_exp.1A_0001"
var = 'T'
value = "output_sd"

vmeans, levs, times = state.calculate_vmean_timeseries(archive, truth, exp, var, value, abs=False)
fig, ax = state.pcolor_vmean_timeseries(vmeans, times, levs, label=var, title=f"{exp}\n{value}", cmap='magma')

# %% [markdown]
# ### Standard deviation ratio

# %%
archive =  "/glade/derecho/scratch/chennuo/archive"
truth = "CESM2_2_BHIST_ne0ARCTICne30x4_g17_derecho_2560pes_spinup_allvars_from_20200701_2mos.004"
exp = "FHIST_exp.1A_0001"
var = 'T'
value = "ratio_sd"

vmeans, levs, times = state.calculate_vmean_timeseries(archive, truth, exp, var, value, abs=False)
fig, ax = state.pcolor_vmean_timeseries(vmeans, times, levs, label=var, title=f"{exp}\n{value}", cmap='magma')
